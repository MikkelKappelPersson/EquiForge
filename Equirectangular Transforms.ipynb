# %% [markdown]
# ## Parameter Reference
#
# - **FOV**: Standard DSLR (60-90°), Wide-angle (100-120°), Smartphone (70-80°)
# - **Yaw**: Left/right rotation (0° = forward)
# - **Pitch**: Up/down rotation (0° = level, positive = up)
# - **Roll**: Clockwise/counterclockwise rotation

# %% [markdown]
# ## Benefits of Using the Package
#
# 1. **Portability**: Process images without opening this notebook
# 2. **Batch Processing**: Can be used in shell scripts to process multiple images
# 3. **Integration**: Can be imported into other Python projects
# 4. **Simplicity**: Clean interface with sensible defaults
#
# The EquiForge package uses the same core algorithm as our notebook but provides a structured API for easier use.

# %% [markdown]
# ## Performance Optimization
#
# To improve processing speed, we've optimized the EquiForge package to use:
#
# 1. **Multi-threading**: Uses multiple CPU cores in parallel
# 2. **Numba JIT Compilation**: Just-in-time compilation for CPU code
# 3. **Numba CUDA**: GPU acceleration that works with most NVIDIA GPUs

# %%
# Import the optimized function from the new package structure
import equiforge

# Time the conversion with optimized code
import time
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image


start_time = time.time()

# Run optimized conversion (will use multiple CPU cores or GPU if available)
optimized_result = equiforge.pers2equi(
    'Images/SamplePerspectiveImage.jpg',
    output_height=4096,
    fov_h=90.0,
    yaw=60.0,
    pitch=30.0,
    roll=90.0
)

end_time = time.time()

# Display the result
plt.figure(figsize=(16, 8))
plt.imshow(optimized_result)
plt.title(f"Optimized conversion (completed in {end_time - start_time:.2f} seconds)")
plt.axis('off')
plt.show()

print(f"Processing completed in {end_time - start_time:.2f} seconds")
# Out:
# Loading image from path: Images/SamplePerspectiveImage.jpg
# Using GPU acceleration...
# pers2equi_gpu completed in 0.44 seconds.
# Processing completed in 1.02 seconds

# %% [markdown]
# ## Using the CLI Tool
#
# You can also use the command-line interface for quick conversions:
#
# ```bash
# # Basic usage
# python -m equiforge.cli Images/Baskettur0047_Cinestill400D.jpg output.jpg
#
# # With parameters
# python -m equiforge.cli Images/Baskettur0047_Cinestill400D.jpg output.jpg --fov 90 --yaw 60 --pitch 0 --roll 0 --height 4096
# ```
